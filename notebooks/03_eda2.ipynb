# %%
# Check if running in Google Colab
if 'google.colab' in str(get_ipython()):
    from google.colab import drive
    drive.mount('/content/drive')

    # Define the base path for your data directory for Colab
    basePath = '/content/drive/MyDrive'

else:
    # Running locally or in a different environment
    basePath = '..'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configure plot styles
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6) # Default figure size
plt.rcParams["font.size"] = 12

# %%
file_path = "data/processed/cleaned_data1.csv"
df = pd.read_csv(f'{basePath}/{file_path}')

# %%
df.head(3)
# Out:
#    COUNTRY      STATION STATION_NAME  DATE  LATITUDE  LONGITUDE  ELEVATION  \
# 0  Tunisia  TS000060765    GABES, TS  1887     33.88       10.1        4.0
# 1  Tunisia  TS000060765    GABES, TS  1889     33.88       10.1        4.0
# 2  Tunisia  TS000060765    GABES, TS  1907     33.88       10.1        4.0
#
#    CDSD  CLDD  DP01  ...  FZF0  FZF5  FZF6  HDSD  HDSD_ATTRIBUTES  HTDD  \
# 0   NaN   NaN  30.0  ...   NaN  -0.3  -2.4   NaN              NaN   NaN
# 1   NaN   NaN   NaN  ...   NaN  -0.1   NaN   NaN              NaN   NaN
# 2   NaN   NaN  19.0  ...   NaN   NaN   NaN   NaN              NaN   NaN
#
#     PRCP  TAVG  TMAX  TMIN
# 0  134.7   NaN   NaN  12.2
# 1    NaN   NaN   NaN  13.7
# 2  109.0   NaN   NaN   NaN
#
# [3 rows x 29 columns]

# %%
df.describe()
# Out:
#                DATE      LATITUDE     LONGITUDE     ELEVATION          CDSD  \
# count  51139.000000  51139.000000  51139.000000  51067.000000  38205.000000
# mean    1974.751071     32.188088     33.631097    373.945293    643.971009
# std       31.971912     33.158155     88.187849    591.915117    956.337583
# min     1781.000000    -90.000000   -179.994700    -23.000000      0.000000
# 25%     1956.000000     17.039000    -13.600300     24.000000     21.900000
# 50%     1978.000000     43.437800     43.300000    118.000000    163.500000
# 75%     2000.000000     55.733100    108.016700    438.000000    834.700000
# max     2025.000000     82.500000    179.217000   3650.000000   4514.100000
#
#                CLDD          DP01          DP10          DT00          DT32  \
# count  38199.000000  42636.000000  42636.000000  41223.000000  41223.000000
# mean     643.839996    120.231471     59.642696     39.348931    126.541712
# std      956.303893     56.788448     37.720668     56.985063     99.516564
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       21.900000     80.000000     32.000000      0.000000     15.000000
# 50%      163.400000    119.000000     54.000000      2.000000    136.000000
# 75%      833.550000    158.000000     78.000000     69.000000    213.000000
# max     4514.100000    329.000000    260.000000    366.000000    366.000000
#
#        ...          FZF0          FZF5          FZF6          HDSD  \
# count  ...  33154.000000  33322.000000  31409.000000  37930.000000
# mean   ...     -1.091775     -1.078135     -3.396921   4319.439470
# std    ...      1.370925      1.380406      1.489757   3317.699712
# min    ...    -32.200000    -31.100000    -31.100000      0.000000
# 25%    ...     -1.600000     -1.500000     -3.900000   1417.925000
# 50%    ...     -0.800000     -0.700000     -3.000000   3875.550000
# 75%    ...     -0.200000     -0.200000     -2.500000   6607.475000
# max    ...      0.000000      0.000000     -2.200000  25336.100000
#
#        HDSD_ATTRIBUTES          HTDD          PRCP          TAVG  \
# count     37930.000000  37928.000000  42682.000000  38848.000000
# mean          4.182731   4319.495805    780.498836      8.229636
# std           3.001307   3317.696692    862.391150     11.088121
# min           0.000000      0.000000      0.000000    -51.100000
# 25%           1.000000   1417.975000    318.800000      0.300000
# 50%           4.000000   3875.550000    547.350000      8.200000
# 75%           7.000000   6607.650000    944.275000     16.700000
# max           9.000000  25336.100000  18805.000000     30.700000
#
#                TMAX          TMIN
# count  41237.000000  41223.000000
# mean      13.595793      3.100956
# std       11.539792     11.000489
# min      -47.900000    -54.200000
# 25%        5.300000     -4.700000
# 50%       13.500000      3.200000
# 75%       22.700000     10.800000
# max       38.600000     27.100000
#
# [8 rows x 26 columns]

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51139 entries, 0 to 51138
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   COUNTRY          51139 non-null  object
#  1   STATION          51139 non-null  object
#  2   STATION_NAME     51139 non-null  object
#  3   DATE             51139 non-null  int64
#  4   LATITUDE         51139 non-null  float64
#  5   LONGITUDE        51139 non-null  float64
#  6   ELEVATION        51067 non-null  float64
#  7   CDSD             38205 non-null  float64
#  8   CLDD             38199 non-null  float64
#  9   DP01             42636 non-null  float64
#  10  DP10             42636 non-null  float64
#  11  DT00             41223 non-null  float64
#  12  DT32             41223 non-null  float64
#  13  DX32             41237 non-null  float64
#  14  DX70             41237 non-null  float64
#  15  DX90             41237 non-null  float64
#  16  EMNT             41223 non-null  float64
#  17  EMXP             42636 non-null  float64
#  18  EMXT             41237 non-null  float64
#  19  FZF0             33154 non-null  float64
#  20  FZF5             33322 non-null  float64
#  21  FZF6             31409 non-null  float64
#  22  HDSD             37930 non-null  float64
#  23  HDSD_ATTRIBUTES  37930 non-null  float64
#  24  HTDD             37928 non-null  float64
#  25  PRCP             42682 non-null  float64
#  26  TAVG             38848 non-null  float64
#  27  TMAX             41237 non-null  float64
#  28  TMIN             41223 non-null  float64
# dtypes: float64(25), int64(1), object(3)
# memory usage: 11.3+ MB
